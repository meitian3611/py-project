# %%
"""
数据可视化
构建 DataFrame --- 创建数据集
"""
import pandas as pd

df = pd.DataFrame([
    {"姓名": "张三", "语文": 80, "数学": 90, "英语": 70, },
    {"姓名": "李四", "语文": 60, "数学": 80, "英语": 90, },
    {"姓名": "王五", "语文": 70, "数学": 60, "英语": 80, },
    {"姓名": "赵六", "语文": 90, "数学": 70, "英语": 60, },
    {"姓名": "孙七", "语文": 80, "数学": 60, "英语": 90, },
])

df.index.tolist()
df.columns.tolist()
df.values.tolist()
df.to_dict(orient="records")
# Out:
# [{'姓名': '张三', '语文': 80, '数学': 90, '英语': 70},
#  {'姓名': '李四', '语文': 60, '数学': 80, '英语': 90},
#  {'姓名': '王五', '语文': 70, '数学': 60, '英语': 80},
#  {'姓名': '赵六', '语文': 90, '数学': 70, '英语': 60},
#  {'姓名': '孙七', '语文': 80, '数学': 60, '英语': 90}]

# %%
"""
构建 Series  --- 创建列
"""
# s1 = pd.Series([80, 90, 70, 60, 80])

s = df["姓名"]
s.tolist()
s.index.tolist()
s.values.tolist()
s.shape
# Out:
# (5,)
